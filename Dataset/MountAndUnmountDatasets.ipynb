# %% [markdown]
# # Mount and unmount dataset

# %%
# !gcsfuse images_dataset_cropped_1 ~/ismiDetectron2/Dataset/TrainData/images
# !gcsfuse testing_dataset_bruno_1 ~/ismiDetectron2/Dataset/TestData/images
# !gcsfuse stain_normalization_train_1 ~/ismiDetectron2/Dataset/StainTrainData/images
# !gcsfuse stain_normalization_test_1 ~/ismiDetectron2/Dataset/StainTestData/images
# Out:
# 2021/06/24 16:09:13.354580 Using mount point: /home/jupyter/ismiDetectron2/Dataset/TrainData/images
# 2021/06/24 16:09:13.365195 Opening GCS connection...
# 2021/06/24 16:09:13.524884 Mounting file system "images_dataset_cropped_1"...
# 2021/06/24 16:09:13.530682 File system has been successfully mounted.
# 2021/06/24 16:09:13.652161 Using mount point: /home/jupyter/ismiDetectron2/Dataset/TestData/images
# 2021/06/24 16:09:13.658984 Opening GCS connection...
# 2021/06/24 16:09:13.824546 Mounting file system "testing_dataset_bruno_1"...
# 2021/06/24 16:09:13.826800 File system has been successfully mounted.
# 2021/06/24 16:09:13.947468 Using mount point: /home/jupyter/ismiDetectron2/Dataset/StainTrainData/images
# 2021/06/24 16:09:13.955098 Opening GCS connection...
# 2021/06/24 16:09:14.148054 Mounting file system "stain_normalization_train_1"...
# 2021/06/24 16:09:14.150610 File system has been successfully mounted.
# ...

# %%
#!fusermount -u ~/ismiDetectron2/Dataset/TestData/images
#!fusermount -u ~/ismiDetectron2/Dataset/TrainData/images
#!fusermount -u ~/ismiDetectron2/Dataset/StainTrainData/images
#!fusermount -u ~/ismiDetectron2/Dataset/StainTestData/images

# %% [markdown]
# # Test if image is there

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
im = cv2.imread('./TrainData/images/001.tiff')
plt.imshow(im)

# %%
im = cv2.imread('./TestData/images/01.tiff')
plt.imshow(im)
